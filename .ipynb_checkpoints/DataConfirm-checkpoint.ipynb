# %%
import numpy as np
from matplotlib import pyplot as plt

import cv2,os
from skimage import io
from PIL import Image, ImageFilter
import matplotlib.image as mpimg

# %%
# ls /home/acd13264yb/DDDog/Datasets/221206SoRa/Ctrl/
# ls /home/acd13264yb/DDDog/Datasets/221206SoRa/VPA/

# %% [markdown]
# # Original data (multi-cells image)

# %%
path_home = "/home/acd13264yb/DDDog/Datasets/221206SoRa/"

path_chip = ["Ctrl/60x_4x_Dapi_test_50nmSTP006/60x_4x_Dapi_test_50nmSTP006_XY00",
             "VPA/VPA_555CTCF_488H3K27AC_DAPI_003/VPA_555CTCF_488H3K27AC_DAPI_003_XY00"]
Chip_status = ["H3K27ac", "CTCF", "Hoechst"]

# %%
path = path_home+path_chip[0]+"1.ome.tif"
print(path)

# img = Image.open(path)
# img = cv2.imread(path,-1)
# img = mpimg.imread(path,-1)
img = io.imread(path)
print(img.shape)
print(type(img))
print(type(img[0,0,0]))

plt.figure(figsize=(20,20))
plt.subplot(1,4,1)
plt.title("Total max: "+str(np.amax(img))+", min: "+str(np.amin(img)))
plt.imshow(img.astype(np.uint8))
if len(img.shape)==3:
    for i in range(3):
        plt.subplot(1,4,i+2)
        plt.title(str(Chip_status[i])+" max: "+str(np.amax(img))+", min: "+str(np.amin(img)))
        plt.imshow(img[:,:,i])
# Out:
# /home/acd13264yb/DDDog/Datasets/221206SoRa/Ctrl/60x_4x_Dapi_test_50nmSTP006/60x_4x_Dapi_test_50nmSTP006_XY001.ome.tif
# (2304, 2304, 3)
# <class 'numpy.ndarray'>
# <class 'numpy.uint16'>
